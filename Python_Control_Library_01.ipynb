# %% [markdown]
# # [Second order system](https://python-control.readthedocs.io/en/0.9.0/secord-matlab.html)

# %%
import os
import matplotlib.pyplot as plt   # MATLAB plotting functions
from control.matlab import *      # MATLAB-like functions

from numpy import linalg as LA    # added by HS for checking eignevalue

# %%
# Parameters defining the system
m = 250.0           # system mass
k = 40.0            # spring constant
b = 60.0            # damping constant

# System matrices
A = [[0, 1.], [-k/m, -b/m]]
B = [[0], [1/m]]
C = [[1., 0]]
sys = ss(A, B, C, 0)

# %%
eigval, normalized_eigvec = LA.eig(A)

# %%
eigval
# Out:
# array([-0.12+0.38157568j, -0.12-0.38157568j])

# %%
# Step response for the system
plt.figure(1)
yout, T = step(sys)
plt.plot(T.T, yout.T)
plt.show(block=False)

# %%
# Bode plot for the system
plt.figure(2)
mag, phase, om = bode(sys, logspace(-2, 2), plot='true')
#plt.show(block=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-e140c41553cd> in <module>
#       1 # Bode plot for the system
#       2 plt.figure(2)
# ----> 3 mag, phase, om = bode(sys, logspace(-2, 2), plot='true')
#       4 #plt.show(block=False)
#
# E:\Anaconda3\lib\site-packages\control\matlab\wrappers.py in bode(*args, **keywords)
#     103
#     104     # Call the bode command
# --> 105     return bode_orig(syslist, omega, **keywords)
#     106
#     107 from ..nichols import nichols_grid
#
# E:\Anaconda3\lib\site-packages\control\freqplot.py in bode_plot(syslist, omega, Plot, omega_limits, omega_num, margins, *args, **kwargs)
#     263                 if dB:
#     264                     pltline = ax_mag.semilogx(omega_plot, 20 * np.log10(mag),
# --> 265                                               *args, **kwargs)
#     266                 else:
#     267                     pltline = ax_mag.loglog(omega_plot, mag, *args, **kwargs)
#
# E:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in semilogx(self, *args, **kwargs)
#    1847
#    1848         self.set_xscale('log', **d)
# -> 1849         l = self.plot(*args, **kwargs)
#    1850         return l
#    1851
#
# E:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# E:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# E:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     403                 "non-matching shapes is deprecated.")
#     404         for j in range(max(ncx, ncy)):
# --> 405             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     406             ret.append(seg)
#     407         return ret
#
# E:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# E:\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         # update kwargs before updating data to give the caller a
#     403         # chance to init axes (and hence unit support)
# --> 404         self.update(kwargs)
#     405         self.pickradius = pickradius
#     406         self.ind_offset = 0
#
# E:\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# E:\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# E:\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'Line2D' object has no property 'plot'
